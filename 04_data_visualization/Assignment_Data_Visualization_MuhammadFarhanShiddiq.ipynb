# %% [markdown]
# ---
# # **INTRUKSI PENGERJAAN**
# 1.   Save file `.ipynb` ini dan copy pada Google Drive Anda. Anda dapat melakukannya dengan cara berikut:
#
#       - Klik menu `file` dan pilih `Save a copy in drive`
#
#
# 2.   Isi identitas Anda terlebih dahulu pada bagian identitas. Anda dapat melakukannya dengan cara berikut:
#
#       - Klik 2x pada bagian `nama`. Jika sudah selesai mengisi, tekan `shift+enter`
#
#
# 3. Anda bisa mendownload data yang digunakan pada link berikut:
#
#     - https://drive.google.com/file/d/1USXIWFIaDMng66CKFDjdMZemJlP4C9LD/view?usp=drive_link
#
#
# 4. Bacalah soal-soal yang ada pada file ipynb dengan teliti. Jika ada pertanyaan terkait soal, silahkan tanya ke mentor Anda
#
#
# 5. _Library_ yang digunakan untuk visualisasi terbatas pada `matplotlib` dan/atau `seaborn`. Anda dipersilahkan menggunakan library lain `hanya untuk` membantu melengkapi atribut data visualisasi
#
#
# 6. Anda dapat membaca `Data Description` untuk mendapatkan penjelasan mengenai kolom-kolom yang ada pada dataset
#
#
# 7. Berikan `comment` atau `text` pada code Anda yang menjelaskan jawaban tersebut menjawab soal nomor berapa
#
#
# 8. Anda dipersilahkan membuat visualisasi dengan kreatifitas Anda yang dapat membantu pembaca memahami visualisasi lebih mudah
# ---

# %% [markdown]
# # **Identitas Diri**
#
# Nama  : Muhammad Farhan Shiddiq
#
# Kelas : DS Batch 20

# %% [markdown]
# # **Data Description**

# %% [markdown]
# ```
# ABOUT DATA
# ----------
# A fictional telco company that provided home phone and Internet services to 7043 customers in California in Q3.
#
# COLUMNS EXPLANATION
# -------------------
# CustomerID: A unique ID that identifies each customer.
#
# Count: A value used in reporting/dashboarding to sum up the number of customers in a filtered set.
#
# Country: The country of the customer’s primary residence.
#
# State: The state of the customer’s primary residence.
#
# City: The city of the customer’s primary residence.
#
# Zip Code: The zip code of the customer’s primary residence.
#
# Lat Long: The combined latitude and longitude of the customer’s primary residence.
#
# Latitude: The latitude of the customer’s primary residence.
#
# Longitude: The longitude of the customer’s primary residence.
#
# Gender: The customer’s gender: Male, Female
#
# Senior Citizen: Indicates if the customer is 65 or older: Yes, No
#
# Partner: Indicate if the customer has a partner: Yes, No
#
# Dependents: Indicates if the customer lives with any dependents: Yes, No. Dependents could be children, parents, grandparents, etc.
#
# Tenure Months: Indicates the total amount of months that the customer has been with the company by the end of the quarter specified above.
#
# Phone Service: Indicates if the customer subscribes to home phone service with the company: Yes, No
#
# Multiple Lines: Indicates if the customer subscribes to multiple telephone lines with the company: Yes, No
#
# Internet Service: Indicates if the customer subscribes to Internet service with the company: No, DSL, Fiber Optic, Cable.
#
# Online Security: Indicates if the customer subscribes to an additional online security service provided by the company: Yes, No
#
# Online Backup: Indicates if the customer subscribes to an additional online backup service provided by the company: Yes, No
#
# Device Protection: Indicates if the customer subscribes to an additional device protection plan for their Internet equipment provided by the company: Yes, No
#
# Tech Support: Indicates if the customer subscribes to an additional technical support plan from the company with reduced wait times: Yes, No
#
# Streaming TV: Indicates if the customer uses their Internet service to stream television programing from a third party provider: Yes, No. The company does not charge an additional fee for this service.
#
# Streaming Movies: Indicates if the customer uses their Internet service to stream movies from a third party provider: Yes, No. The company does not charge an additional fee for this service.
#
# Contract: Indicates the customer’s current contract type: Month-to-Month, One Year, Two Year.
#
# Paperless Billing: Indicates if the customer has chosen paperless billing: Yes, No
#
# Payment Method: Indicates how the customer pays their bill: Bank Withdrawal, Credit Card, Mailed Check
#
# Monthly Charge: Indicates the customer’s current total monthly charge for all their services from the company.
#
# Total Charges: Indicates the customer’s total charges, calculated to the end of the quarter specified above.
#
# Churn Label: Yes = the customer left the company this quarter. No = the customer remained with the company. Directly related to Churn Value.
#
# Churn Value: 1 = the customer left the company this quarter. 0 = the customer remained with the company. Directly related to Churn Label.
#
# Churn Score: A value from 0-100 that is calculated using the predictive tool IBM SPSS Modeler. The model incorporates multiple factors known to cause churn. The higher the score, the more likely the customer will churn.
#
# CLTV: Customer Lifetime Value. A predicted CLTV is calculated using corporate formulas and existing data. The higher the value, the more valuable the customer. High value customers should be monitored for churn.
#
# Churn Reason: A customer’s specific reason for leaving the company. Directly related to Churn Category.
# ```

# %% [markdown]
# # **Soal Assignment**
#
# 1.   Buatlah visualiasi untuk menemukan perbedaan persentase dari `customer yang churn` dan `customer yang tidak churn`
# 2.   Buatlah visualisasi untuk melihat hubungan antara `jumlah bulan yang telah dihabiskan customer` di perusahaan pada akhir kuartal dan `total tagihan customer`
# 3.   Buatlah visualisasi untuk melihat 5 `kota` teratas yang customernya melakukan churn dan tidak melakukan churn
# 4.   Buatlah visualisasi untuk melihat persebaran data dari `tenure months` untuk masing-masing `churn label`
# 5.   Jelaskan insight dan saran action yang Anda dapatkan pada setiap visualisasi

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

url = 'https://raw.githubusercontent.com/mfarhanshiddiq/Dataset/main/Telco_customer_churn.csv'
df_TCC = pd.read_csv(url)

df_TCC.head(5)
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender  ...        Contract  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...  Month-to-month
# 1   34.059281, -118.30742  34.059281 -118.307420  Female  ...  Month-to-month
# 2  34.048013, -118.293953  34.048013 -118.293953  Female  ...  Month-to-month
# 3  34.062125, -118.315709  34.062125 -118.315709  Female  ...  Month-to-month
# 4  34.039224, -118.266293  34.039224 -118.266293    Male  ...  Month-to-month
#
# ...

# %%
df_TCC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %% [markdown]
# **1. Visualisasi perbedaan presentase Customer Churn dan Tidak Churn**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

plt.figure(figsize=(7,5))

ax = sns.countplot(
    data=df_TCC,
    x='Churn Label',
    hue='Churn Label',
    palette='Set2',
    legend=False
)

total = len(df_TCC)

for p in ax.patches:
    percentage = f'{100 * p.get_height() / total:.1f}%' # type: ignore

    ax.annotate(
        percentage,
        (p.get_x() + p.get_width()/2., p.get_height()), # type: ignore
        ha='center',
        va='bottom',
        fontsize=11
    )

plt.title('Persentase Customer Churn vs Tidak Churn')
plt.xlabel('Churn Status')
plt.ylabel('Jumlah Customer')

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))

churn_reason = df_TCC[df_TCC['Churn Label'] == 'Yes']

ax = sns.countplot(
    data=churn_reason,
    y='Churn Reason',
    hue='Churn Reason',
    order=churn_reason['Churn Reason'].value_counts().index,
    palette='Blues_r',
    legend=False
)

for p in ax.patches:
    ax.annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2.), # type: ignore
                ha='left', va='center', fontsize=10, color='black')

plt.title('Alasan Customer Melakukan Churn')
plt.xlabel('Jumlah Customer')
plt.ylabel('Churn Reason')

plt.show()

# %% [markdown]
# Dari grafik di atas dapat disimpulkan presenatase customer yang melakukan churn sebanyak 26,5% dan yang tidak melakukan churn 73,5%, dengan alasan terbanyak "attitude of support person" sebanyak 192 customers.

# %% [markdown]
# **2. Visualisasi untuk melihat hubungan antara jumlah bulan yang telah dihabiskan customer di perusahaan pada akhir kuartal dan total tagihan customer**

# %%
df_TCC['Total Charges'] = pd.to_numeric(df_TCC['Total Charges'], errors='coerce')

# %%
plt.figure(figsize=(8,6))

sns.scatterplot(
    data=df_TCC,
    x='Tenure Months',
    y='Total Charges',
    hue='Churn Label',
    alpha=0.6
)

sns.regplot(
    data=df_TCC,
    x='Tenure Months',
    y='Total Charges',
    scatter=False,
    color='black'
)

plt.title('Hubungan Tenure Months dengan Total Charges')
plt.xlabel('Tenure Months')
plt.ylabel('Total Charges')

plt.show()

# %% [markdown]
# Berdasarkan visualisasi scatter plot antara Tenure Months dan Total Charges, terlihat adanya hubungan positif antara kedua variabel tersebut. Semakin lama customer berlangganan, maka semakin besar total biaya yang telah dibayarkan. Selain itu, customer yang melakukan churn lebih banyak ditemukan pada tenure yang rendah, sedangkan customer dengan tenure yang tinggi cenderung tetap menggunakan layanan perusahaan.

# %% [markdown]
# **3. Visualisasi 5 kota teratas customer yang melakukan churn dan tidak churn**

# %%
sns.set_theme(style="whitegrid")

# Ambil 5 kota dengan jumlah customer terbanyak
top5_city = df_TCC['City'].value_counts().head(5).index

# Filter dataset hanya untuk 5 kota tersebut
df_top_city = df_TCC[df_TCC['City'].isin(top5_city)]

plt.figure(figsize=(12,7))

ax = sns.countplot(
    data=df_top_city,
    x='City',
    hue='Churn Label',
    order=top5_city,
    palette='viridis'
)

for p in ax.patches:
    ax.annotate(
        int(p.get_height()), # type: ignore
        (p.get_x() + p.get_width()/2., p.get_height()), # type: ignore
        ha='center',
        va='bottom',
        fontsize=10
    )

plt.title('5 Kota Teratas Customer Churn dan Tidak Churn')
plt.xlabel('City')
plt.ylabel('Jumlah Customer')

plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan visualisasi, beberapa kota memiliki jumlah customer churn yang lebih tinggi dibanding kota lainnya. Hal ini menunjukkan bahwa faktor geografis dapat mempengaruhi tingkat churn pelanggan. Kota dengan churn tinggi mungkin dipengaruhi oleh kualitas layanan, harga paket, atau kompetitor yang lebih kuat di wilayah tersebut.

# %% [markdown]
# **4. Visualisasi untuk melihat persebaran data dari tenure months untuk masing-masing churn label**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

plt.figure(figsize=(8,6))

sns.histplot(
    data=df_TCC,
    x='Tenure Months',
    hue='Churn Label',
    bins=30,
    kde=True,
    palette='Set2'
)

plt.title('Distribusi Tenure Months Berdasarkan Churn Label')
plt.xlabel('Tenure Months')
plt.ylabel('Jumlah Customer')

plt.show()

# %% [markdown]
# Berdasarkan visualisasi distribusi Tenure Months berdasarkan Churn Label, terlihat bahwa customer yang melakukan churn cenderung memiliki tenure yang lebih rendah dibandingkan dengan customer yang tidak churn. Hal ini menunjukkan bahwa pelanggan baru lebih rentan untuk berhenti menggunakan layanan perusahaan.

# %% [markdown]
# **5. Jelaskan insight dan saran action yang Anda dapatkan pada setiap visualisasi**

# %% [markdown]
# 1. Visualisasi Persentase Customer Churn vs Tidak Churn
#
#     Berdasarkan visualisasi, terlihat bahwa jumlah customer yang tidak melakukan churn lebih banyak dibandingkan dengan customer yang churn. Namun, jumlah customer yang churn masih cukup signifikan sehingga dapat berdampak pada penurunan jumlah pelanggan dan potensi pendapatan perusahaan.
#
# Rekomendasi:
#
# + Perusahaan dapat melakukan beberapa strategi untuk mengurangi churn, seperti:
#
# + Meningkatkan kualitas layanan dan customer experience.
#
# + Memberikan promo atau diskon bagi pelanggan yang berpotensi churn.
#
# + Mengembangkan program loyalitas pelanggan untuk mempertahankan pelanggan yang sudah ada.
#
# 2. Visualisasi Hubungan Tenure Months dengan Total Charges
#
#     Dari visualisasi scatter plot terlihat adanya hubungan positif antara Tenure Months dan Total Charges, di mana semakin lama customer menggunakan layanan perusahaan maka semakin besar total biaya yang telah dibayarkan. Selain itu, customer yang melakukan churn cenderung memiliki tenure yang lebih rendah, sedangkan customer yang tidak churn umumnya memiliki tenure yang lebih tinggi.
#
# Rekomendasi:
#
# + Perusahaan dapat fokus pada retensi pelanggan baru, karena pelanggan dengan masa berlangganan yang masih pendek memiliki kemungkinan churn yang lebih tinggi. Beberapa strategi yang dapat dilakukan antara lain:
#
# + Memberikan promo atau penawaran khusus pada pelanggan baru.
#
# + Meningkatkan kualitas onboarding pelanggan pada awal masa berlangganan.
#
# + Memberikan insentif atau reward bagi pelanggan yang tetap berlangganan dalam jangka waktu tertentu.
#
# 3. Visualisasi 5 Kota Teratas Customer yang Churn dan Tidak Churn
#
#     Berdasarkan visualisasi terlihat bahwa terdapat beberapa kota dengan jumlah customer churn yang cukup tinggi dibandingkan kota lainnya. Hal ini menunjukkan bahwa faktor geografis atau kondisi pasar di suatu wilayah dapat mempengaruhi tingkat churn pelanggan.
#
# Rekomendasi:
#
# + Perusahaan dapat melakukan analisis lebih lanjut pada kota dengan tingkat churn tinggi untuk mengetahui penyebabnya. Beberapa langkah yang dapat dilakukan antara lain:
#
# + Meningkatkan kualitas jaringan atau layanan di wilayah tersebut.
#
# + Memberikan promo atau paket khusus untuk pelanggan di kota dengan churn tinggi.
#
# + Melakukan evaluasi terhadap kompetitor di wilayah tersebut.
#
# 4. Visualisasi Persebaran Tenure Months Berdasarkan Churn Label
#
#     Dari visualisasi distribusi tenure months terlihat bahwa customer yang melakukan churn cenderung memiliki masa berlangganan yang lebih pendek, sedangkan customer yang tidak churn umumnya memiliki tenure yang lebih panjang. Hal ini menunjukkan bahwa pelanggan baru lebih rentan untuk berhenti menggunakan layanan dibandingkan pelanggan lama.
#
# Rekomendasi:
#
# + Perusahaan perlu memberikan perhatian lebih pada pelanggan baru agar mereka tetap menggunakan layanan perusahaan. Strategi yang dapat dilakukan antara lain:
#
# + Memberikan penawaran khusus pada beberapa bulan pertama berlangganan.
#
# + Meningkatkan kualitas pelayanan pada fase awal penggunaan layanan.
#
# + Membuat program loyalitas bagi pelanggan yang telah berlangganan dalam jangka waktu tertentu.
